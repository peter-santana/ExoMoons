# %%
import exomlib
import numpy as np
import matplotlib.pyplot as plt

# make plots inline
# %matplotlib inline

# %%
# star properties
mass_star = 0.99 # solar masses

# planet properties
planet_name = "HD 4113 b"
mass_planet = 1.56 # jupiter masses
a_planet = 1.28 # AU, astronomical units
e_planet = 0.9 # eccentricity
planet_radius = (mass_planet**0.5)

# moon properties
e_moon = 0 # moon eccentricity   
a_moon = 1 #lunar distance
mass_moon = 1 # earth masses

n_orbits = 100 #Number of orbits
n_points_orbit = 10 #Number of points per orbit

# %%
# Distance and Mass Variator
while a_moon<=5: 
    while mass_moon<=5:
        data = exomlib.exomoon_orbit1(mass_star = mass_star, mass_planet = mass_planet, 
                                      a_planet = a_planet, e_planet = e_planet, mass_moon = mass_moon, 
                                      a_moon = a_moon, e_moon = e_moon, n_orbits = n_orbits, 
                                      n_points_orbit = n_points_orbit)
        #Figure 1
        fig = plt.figure(figsize = (15,10))
        ax1 = plt.subplot(211)
        # ax1.set_xlabel('Time (years)')
        ax1.set_ylabel('Planet semi-major axis (AU)')
        plt.plot(data.t/(2*np.pi), data.a);
        ax2 = plt.subplot(212, sharex = ax1)
        ax2.set_xlabel('Time (years)')
        ax2.set_ylabel('Moon distance (lunar distances)')
        plt.plot(data.t/(2*np.pi), data.d);
        plt.subplots_adjust(hspace = 0.0)
        plt.savefig('Planet SMA and Moon Distance')
        
        #Figure2
        fig = plt.figure(figsize = (5,5))
        ax = plt.subplot(111)
        ax.set_xlabel('Distance (AU)')
        ax.set_ylabel('Distance (AU)')
        plt.plot(data.xs, data.ys, color = 'black');
        plt.plot(data.x, data.y, color = 'red', label = 'moon');
        plt.plot(data.xp, data.yp, color = 'blue', label = 'planet');
        plt.legend(frameon = False);
        plt.savefig('Orbits')
        
        mass_moon+=1 #step increase
        
    a_moon+=1 #step increase
    mass_moon = 1 #reset steps
# Out:
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             1.0
#             100              14             1.3             1.0
#             200              29             1.3             1.0
#             300              43             1.3             1.0
#             400              58             1.3             1.0
#             500              72             1.3             1.0
#             600              87             1.3             1.0
#             700             101             1.3             1.0
#             800             116             1.3             1.0
#             900             131             1.3             1.0
#             100             145             1.3             1.0
# ---------------------------------------------------------------
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             1.0
#             100              14             1.3             1.0
#             200              29             1.3             1.0
#             300              43             1.3             1.0
#             400              58             1.3             1.0
#             500              72             1.3             1.0
#             600              87             1.3             1.0
#             700             101             1.3             1.0
#             800             116             1.3             1.0
#             900             131             1.3             1.0
#             100             145             1.3             1.0
# ---------------------------------------------------------------
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             1.0
#             100              14             1.3             1.0
#             200              29             1.3             1.0
#             300              43             1.3             1.0
#             400              58             1.3             1.0
#             500              72             1.3             1.0
#             600              87             1.3             1.0
#             700             101             1.3             1.0
#             800             116             1.3             1.0
#             900             131             1.3             1.0
#             100             145             1.3             1.0
# ---------------------------------------------------------------
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             1.0
#             100              14             1.3             1.0
#             200              29             1.3             1.0
#             300              43             1.3             1.0
#             400              58             1.3             1.0
#             500              72             1.3             1.0
#             600              87             1.3             1.0
#             700             101             1.3             1.0
#             800             116             1.3             1.0
#             900             131             1.3             1.0
#             100             145             1.3             1.0
# ---------------------------------------------------------------
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             1.0
#             100              14             1.3             1.0
#             200              29             1.3             1.0
#             300              43             1.3             1.0
#             400              58             1.3             1.0
#             500              72             1.3             1.0
#             600              87             1.3             1.0
#             700             101             1.3             1.0
#             800             116             1.3             1.0
#             900             131             1.3             1.0
#             100             145             1.2             1.0
# ---------------------------------------------------------------
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             2.0
#             100              14             1.3             1.5
#             200              29             1.3           834.4
#             300              43             1.3           713.2
#             400              58             1.3           362.5
#             500              72             1.3           274.8
#             600              87             1.3           608.5
#             700             101             1.3           887.5
#             800             116             1.3           923.8
#             900             131             1.3           756.4
#             100             145             1.3           291.1
# ---------------------------------------------------------------
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             2.0
#             100              14             1.3          1787.4
#             200              29             1.3         39153.5
#             300              43             1.3         76154.2
#             400              58             1.3        112892.0
#             500              72             1.3        149060.2
#             600              87             1.3        185532.8
#             700             101             1.3        222147.0
#             800             116             1.3        258883.4
#             900             131             1.3        295771.7
#             100             145             1.3        332171.9
# ---------------------------------------------------------------
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             2.0
#             100              14             1.3             5.7
#             200              29             1.3         41451.9
#             300              43             1.3         84621.2
#             400              58             1.3        127370.2
#             500              72             1.3        170598.9
#             600              87             1.3        214204.2
#             700             101             1.3        256502.6
#             800             116             1.3        299587.6
#             900             131             1.3        343096.0
#             100             145             1.3        385339.2
# ---------------------------------------------------------------
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             2.0
#             100              14             1.3             1.1
#             200              29             1.3           143.0
#             300              43             1.3           912.7
#             400              58             1.3           212.2
#             500              72             1.3           886.2
#             600              87             1.3           397.7
#             700             101             1.3           776.6
#             800             116             1.3           696.5
#             900             131             1.3           753.3
#             100             145             1.3           424.2
# ---------------------------------------------------------------
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             2.0
#             100              14             1.3             1.1
#             200              29             1.3             1.8
#             300              43             1.3             1.2
#             400              58             1.3             1.6
#             500              72             1.3             2.2
#             600              87             1.3             2.1
#             700             101             1.3             1.1
#             800             116             1.3             2.0
#             900             131             1.3             1.8
#             100             145             1.3             2.0
# ---------------------------------------------------------------
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             3.0
#             100              14             1.3           824.9
#             200              29             1.3           769.0
#             300              43             1.3           675.4
#             400              58             1.3           625.3
#             500              72             1.3           600.7
#             600              87             1.3           605.9
#             700             101             1.3           542.5
#             800             116             1.3           690.2
#             900             131             1.3           338.4
#             100             145             1.3            34.2
# ---------------------------------------------------------------
# <ipython-input-3-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-3-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             3.0
#             100              14             1.3           788.8
#             200              29             1.3           241.2
#             300              43             1.3           638.7
#             400              58             1.3           694.3
#             500              72             1.3           721.8
#             600              87             1.3           444.6
#             700             101             1.3           488.7
#             800             116             1.3           644.6
#             900             131             1.3           318.3
#             100             145             1.3           309.9
# ---------------------------------------------------------------
# <ipython-input-3-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-3-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             3.0
#             100              14             1.3           884.5
#             200              29             1.3           334.9
#             300              43             1.3           460.2
#             400              58             1.3           393.0
#             500              72             1.3           334.8
#             600              87             1.3           747.7
#             700             101             1.3           644.3
#             800             116             1.3           377.5
#             900             131             1.3           650.7
#             100             145             1.3           457.7
# ---------------------------------------------------------------
# <ipython-input-3-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-3-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             3.0
#             100              14             1.3         23997.1
#             200              29             1.3         48421.1
#             300              43             1.3         71932.6
#             400              58             1.3         95312.9
#             500              72             1.3        118935.5
#             600              87             1.3        142776.4
#             700             101             1.3        167013.2
#             800             116             1.3        189846.8
#             900             131             1.3        213224.7
#             100             145             1.3        236546.6
# ---------------------------------------------------------------
# <ipython-input-3-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-3-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             3.0
#             100              14             1.2         35736.2
#             200              29             1.2         76521.5
#             300              43             1.2        118010.9
#             400              58             1.2        158915.8
#             500              72             1.2        200167.9
#             600              87             1.2        241278.8
#             700             101             1.2        282315.2
#             800             116             1.2        323679.5
#             900             131             1.2        364472.2
#             100             145             1.2        405711.5
# ---------------------------------------------------------------
# <ipython-input-3-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-3-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             4.0
#             100              14             1.3           755.5
#             200              29             1.3           754.9
#             300              43             1.3           647.5
#             400              58             1.3           585.8
#             500              72             1.3           435.5
#             600              87             1.3           237.3
#             700             101             1.3           203.7
#             800             116             1.3           431.5
#             900             131             1.3           624.6
#             100             145             1.3           684.4
# ---------------------------------------------------------------
# <ipython-input-3-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-3-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             4.0
#             100              14             1.3         57343.4
#             200              29             1.3        117170.8
#             300              43             1.3        177030.5
#             400              58             1.3        237291.9
#             500              72             1.3        297179.7
#             600              87             1.3        356937.5
#             700             101             1.3        417146.2
#             800             116             1.3        477160.0
#             900             131             1.3        536814.8
#             100             145             1.3        596276.9
# ---------------------------------------------------------------
# <ipython-input-3-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-3-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             4.0
#             100              14             1.2         52875.4
#             200              29             1.2        107434.1
#             300              43             1.2        162684.3
#             400              58             1.2        217540.6
#             500              72             1.2        272495.7
#             600              87             1.2        328028.3
#             700             101             1.2        382368.1
#             800             116             1.2        437682.4
#             900             131             1.2        492337.3
#             100             145             1.2        546781.2
# ---------------------------------------------------------------
# <ipython-input-3-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-3-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             4.0
#             100              14             1.2         45681.1
#             200              29             1.2         92443.5
#             300              43             1.2        140045.5
#             400              58             1.2        186998.2
#             500              72             1.2        234359.5
#             600              87             1.2        281596.9
#             700             101             1.2        328692.6
#             800             116             1.2        376508.0
#             900             131             1.2        423059.7
#             100             145             1.2        470091.9
# ---------------------------------------------------------------
# <ipython-input-3-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-3-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             4.0
#             100              14             1.2         36391.4
#             200              29             1.2         77889.3
#             300              43             1.2        120167.5
#             400              58             1.2        161740.3
#             500              72             1.2        203817.6
#             600              87             1.2        245546.9
#             700             101             1.2        287449.1
#             800             116             1.2        329363.9
#             900             131             1.2        371082.0
#             100             145             1.2        413181.2
# ---------------------------------------------------------------
# <ipython-input-3-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-3-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             5.0
#             100              14             1.3           725.4
#             200              29             1.3           682.7
#             300              43             1.3           795.0
#             400              58             1.3           507.9
#             500              72             1.3           223.2
#             600              87             1.3           225.6
#             700             101             1.3           460.2
#             800             116             1.3           619.4
#             900             131             1.3           766.7
#             100             145             1.3           807.4
# ---------------------------------------------------------------
# <ipython-input-3-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-3-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             5.0
#             100              14             1.3           791.5
#             200              29             1.3           560.2
#             300              43             1.3           233.4
#             400              58             1.3           269.9
#             500              72             1.3           575.2
#             600              87             1.3           581.2
#             700             101             1.3           616.2
#             800             116             1.3           734.5
#             900             131             1.3           922.5
#             100             145             1.3           489.2
# ---------------------------------------------------------------
# <ipython-input-3-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-3-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             5.0
#             100              14             1.3           552.4
#             200              29             1.3           240.6
#             300              43             1.3           316.8
#             400              58             1.3           601.0
#             500              72             1.3           746.8
#             600              87             1.3           624.1
#             700             101             1.3           631.0
#             800             116             1.3           427.3
#             900             131             1.3           208.4
#             100             145             1.3           434.8
# ---------------------------------------------------------------
# <ipython-input-3-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-3-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             5.0
#             100              14             1.2         58662.1
#             200              29             1.2        120444.4
#             300              43             1.2        181738.7
#             400              58             1.2        243510.3
#             500              72             1.2        305102.3
#             600              87             1.2        366415.3
#             700             101             1.2        428314.0
#             800             116             1.2        489715.1
#             900             131             1.2        551066.1
#             100             145             1.2        612471.6
# ---------------------------------------------------------------
# <ipython-input-3-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-3-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.3             5.0
#             100              14             1.2         51726.6
#             200              29             1.2        106155.4
#             300              43             1.2        160002.2
#             400              58             1.2        214209.6
#             500              72             1.2        268549.7
#             600              87             1.2        322369.4
#             700             101             1.2        376570.1
#             800             116             1.2        430878.9
#             900             131             1.2        484695.0
#             100             145             1.2        538740.5
# ---------------------------------------------------------------
# <ipython-input-3-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-3-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
