# %%
import exomlib
import numpy as np
import matplotlib.pyplot as plt

# make plots inline
# %matplotlib inline

# %%
# star properties
mass_star = 1.07 # solar masses

# planet properties
mass_planet = 1.49 # jupiter masses
a_planet = 1.36 # AU, astronomical units
e_planet = 0.95 # eccentricity
planet_radius = (mass_planet**0.5)

# moon properties
e_moon = 0 # moon eccentricity   
a_moon = 1 #lunar distance
mass_moon = 1 # earth masses

n_orbits = 10 #Number of orbits
n_points_orbit = 1 #Number of points per orbit

# %%
# Distance and Mass Variator
while a_moon<=5: 
    while mass_moon<=5:
        data = exomlib.exomoon_orbit1(mass_star = mass_star, mass_planet = mass_planet, 
                                      a_planet = a_planet, e_planet = e_planet, mass_moon = mass_moon, 
                                      a_moon = a_moon, e_moon = e_moon, n_orbits = n_orbits, 
                                      n_points_orbit = n_points_orbit)
        #Figure 1
        fig = plt.figure(figsize = (15,10))
        ax1 = plt.subplot(211)
        # ax1.set_xlabel('Time (years)')
        ax1.set_ylabel('Planet semi-major axis (AU)')
        plt.plot(data.t/(2*np.pi), data.a);
        ax2 = plt.subplot(212, sharex = ax1)
        ax2.set_xlabel('Time (years)')
        ax2.set_ylabel('Moon distance (lunar distances)')
        plt.plot(data.t/(2*np.pi), data.d);
        plt.subplots_adjust(hspace = 0.0)
        plt.savefig('Planet SMA and Moon Distance')
        
        #Figure2
        fig = plt.figure(figsize = (5,5))
        ax = plt.subplot(111)
        ax.set_xlabel('Distance (AU)')
        ax.set_ylabel('Distance (AU)')
        plt.plot(data.xs, data.ys, color = 'black');
        plt.plot(data.x, data.y, color = 'red', label = 'moon');
        plt.plot(data.xp, data.yp, color = 'blue', label = 'planet');
        plt.legend(frameon = False);
        plt.savefig('Orbits')
        
        mass_moon+=1 #step increase
        
    a_moon+=1 #step increase
    mass_moon = 1 #reset steps
# Out:
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             1.0
#               1               1             1.4             1.2
#               2               3             1.4             1.1
#               3               5             1.4             1.0
#               4               6             1.4             1.1
#               5               8             1.3             0.4
#               6              10             1.4             1.1
#               7              11             1.4             1.3
#               8              13             1.4           908.0
#               9              15             1.4           902.3
#              10              15             1.4           902.3
# ---------------------------------------------------------------
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             1.0
#               1               1             1.4             0.7
#               2               3             1.4             0.7
#               3               5             1.4             0.7
#               4               6             1.4             0.5
#               5               8             1.4             1.1
#               6              10             1.4             0.9
#               7              11             1.4             1.2
#               8              13             1.4             1.2
#               9              15             1.4             1.0
#              10              15             1.4             1.0
# ---------------------------------------------------------------
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             1.0
#               1               1             1.4             1.0
#               2               3             1.4             1.1
#               3               5             1.4             1.0
#               4               6             1.3             1.2
#               5               8             1.4             0.8
#               6              10             1.4             1.1
#               7              11             1.4             1.2
#               8              13             1.4             0.8
#               9              15             1.4             0.9
#              10              15             1.4             0.9
# ---------------------------------------------------------------
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             1.0
#               1               1             1.4             0.9
#               2               3             1.4             1.0
#               3               5             1.4             1.0
#               4               6             1.4             0.8
#               5               8             1.3             0.9
#               6              10             1.4             1.1
#               7              11             1.4             1.0
#               8              13             1.4             1.0
#               9              15             1.4             1.0
#              10              15             1.4             1.0
# ---------------------------------------------------------------
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             1.0
#               1               1             1.4             1.0
#               2               3             1.4             1.0
#               3               5             1.4             1.0
#               4               6             1.4             0.9
#               5               8             1.4             1.1
#               6              10             1.4             1.1
#               7              11             1.4             1.0
#               8              13             1.4             1.1
#               9              15             1.4             1.1
#              10              15             1.4             1.1
# ---------------------------------------------------------------
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             2.0
#               1               1             1.3          3721.1
#               2               3             1.3         11310.3
#               3               5             1.3         18974.7
#               4               6             1.3         26581.4
#               5               8             1.3         33533.1
#               6              10             1.3         40753.0
#               7              11             1.3         48080.4
#               8              13             1.3         55487.1
#               9              15             1.3         62967.3
#              10              15             1.3         62967.3
# ---------------------------------------------------------------
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             2.0
#               1               1             1.4           927.0
#               2               3             1.4          1000.4
#               3               5             1.4           889.8
#               4               6             1.4           786.3
#               5               8             1.4           752.6
#               6              10             1.4           680.7
#               7              11             1.4           452.2
#               8              13             1.4           297.8
#               9              15             1.4            59.8
#              10              15             1.4            59.8
# ---------------------------------------------------------------
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             2.0
#               1               1             1.3          5175.8
#               2               3             1.3         15342.6
#               3               5             1.3         25110.1
#               4               6             1.3         34735.7
#               5               8             1.3         44603.6
#               6              10             1.3         54622.8
#               7              11             1.3         64813.9
#               8              13             1.3         74409.6
#               9              15             1.3         84085.4
#              10              15             1.3         84085.4
# ---------------------------------------------------------------
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             2.0
#               1               1             1.4             0.8
#               2               3             1.3          5083.2
#               3               5             1.3         13691.3
#               4               6             1.3         21251.5
#               5               8             1.3         29225.6
#               6              10             1.3         37386.0
#               7              11             1.3         45711.7
#               8              13             1.3         54316.1
#               9              15             1.3         61768.4
#              10              15             1.3         61768.4
# ---------------------------------------------------------------
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             2.0
#               1               1             1.5          1092.8
#               2               3             1.5          1018.1
#               3               5             1.5           986.9
#               4               6             1.5          1092.3
#               5               8             1.5           984.2
#               6              10             1.5          1031.5
#               7              11             1.5           965.9
#               8              13             1.5           995.1
#               9              15             1.5           997.0
#              10              15             1.5           997.0
# ---------------------------------------------------------------
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             3.0
#               1               1             1.4           987.5
#               2               3             1.4           797.7
#               3               5             1.4           636.5
#               4               6             1.4           509.3
#               5               8             1.4           160.3
#               6              10             1.4           437.9
#               7              11             1.4           682.1
#               8              13             1.4           822.4
#               9              15             1.4           880.1
#              10              15             1.4           880.1
# ---------------------------------------------------------------
# <ipython-input-8-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-8-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             3.0
#               1               1             1.3          5739.1
#               2               3             1.3         16631.6
#               3               5             1.3         27382.7
#               4               6             1.3         37756.4
#               5               8             1.3         48408.9
#               6              10             1.3         59171.0
#               7              11             1.3         70022.5
#               8              13             1.3         80981.7
#               9              15             1.3         91295.1
#              10              15             1.3         91295.1
# ---------------------------------------------------------------
# <ipython-input-8-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-8-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             3.0
#               1               1             1.3          4353.2
#               2               3             1.3         12540.6
#               3               5             1.3         20760.6
#               4               6             1.3         28288.2
#               5               8             1.3         36205.6
#               6              10             1.3         44232.9
#               7              11             1.3         52344.8
#               8              13             1.3         60550.0
#               9              15             1.3         68349.1
#              10              15             1.3         68349.1
# ---------------------------------------------------------------
# <ipython-input-8-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-8-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             3.0
#               1               1             1.3          3524.7
#               2               3             1.3         10705.7
#               3               5             1.3         17966.4
#               4               6             1.3         24310.0
#               5               8             1.3         31051.3
#               6              10             1.3         37949.0
#               7              11             1.3         44981.5
#               8              13             1.3         52190.4
#               9              15             1.3         58868.2
#              10              15             1.3         58868.2
# ---------------------------------------------------------------
# <ipython-input-8-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-8-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             3.0
#               1               1             1.5          1001.0
#               2               3             1.5          1043.1
#               3               5             1.5           992.2
#               4               6             1.5          1095.5
#               5               8             1.5           996.0
#               6              10             1.5          1012.0
#               7              11             1.5          1009.5
#               8              13             1.5           948.2
#               9              15             1.5           995.7
#              10              15             1.5           995.7
# ---------------------------------------------------------------
# <ipython-input-8-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-8-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             4.0
#               1               1             1.4           809.6
#               2               3             1.4           723.7
#               3               5             1.4           645.1
#               4               6             1.4           526.1
#               5               8             1.4           129.8
#               6              10             1.4           346.7
#               7              11             1.4           594.3
#               8              13             1.4           788.9
#               9              15             1.4           973.2
#              10              15             1.4           973.2
# ---------------------------------------------------------------
# <ipython-input-8-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-8-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             4.0
#               1               1             1.4           770.4
#               2               3             1.4           709.2
#               3               5             1.4           588.2
#               4               6             1.4           419.5
#               5               8             1.4           162.5
#               6              10             1.4           252.4
#               7              11             1.4           612.6
#               8              13             1.4           689.9
#               9              15             1.4           725.4
#              10              15             1.4           725.4
# ---------------------------------------------------------------
# <ipython-input-8-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-8-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             4.0
#               1               1             1.3          4282.1
#               2               3             1.3         12331.8
#               3               5             1.3         20483.4
#               4               6             1.3         27820.2
#               5               8             1.3         35593.1
#               6              10             1.3         43476.7
#               7              11             1.3         51443.8
#               8              13             1.3         59500.7
#               9              15             1.3         67244.1
#              10              15             1.3         67244.1
# ---------------------------------------------------------------
# <ipython-input-8-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-8-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# <ipython-input-8-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             4.0
#               1               1             1.3          3740.5
#               2               3             1.3         10716.8
#               3               5             1.3         17707.8
#               4               6             1.3         24011.9
#               5               8             1.3         30693.7
#               6              10             1.3         37487.2
#               7              11             1.3         44368.0
#               8              13             1.3         51347.9
#               9              15             1.3         57899.6
#              10              15             1.3         57899.6
# ---------------------------------------------------------------
# <ipython-input-8-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# <ipython-input-8-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             4.0
#               1               1             1.3          3539.8
#               2               3             1.3         10245.3
#               3               5             1.3         16762.1
#               4               6             1.3         22874.6
#               5               8             1.3         29261.7
#               6              10             1.3         35771.8
#               7              11             1.3         42391.3
#               8              13             1.3         49167.3
#               9              15             1.3         55088.5
#              10              15             1.3         55088.5
# ---------------------------------------------------------------
# <ipython-input-8-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# <ipython-input-8-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             5.0
#               1               1             1.4          1893.5
#               2               3             1.4          6018.2
#               3               5             1.4         10096.1
#               4               6             1.4         14314.8
#               5               8             1.4         17756.0
#               6              10             1.4         21223.5
#               7              11             1.4         24810.8
#               8              13             1.4         28476.9
#               9              15             1.4         32211.1
#              10              15             1.4         32211.1
# ---------------------------------------------------------------
# <ipython-input-8-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             5.0
#               1               1             1.4          1005.4
#               2               3             1.4           850.1
#               3               5             1.4           767.5
#               4               6             1.4           597.7
#               5               8             1.4           567.8
#               6              10             1.4           133.5
#               7              11             1.4           278.8
#               8              13             1.4           478.1
#               9              15             1.4           623.0
#              10              15             1.4           623.0
# ---------------------------------------------------------------
# <ipython-input-8-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-8-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             5.0
#               1               1             1.4           821.3
#               2               3             1.4           785.6
#               3               5             1.4           788.3
#               4               6             1.4           554.0
#               5               8             1.4           392.1
#               6              10             1.4           175.0
#               7              11             1.4           272.6
#               8              13             1.4           401.4
#               9              15             1.4           679.8
#              10              15             1.4           679.8
# ---------------------------------------------------------------
# <ipython-input-8-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-8-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             5.0
#               1               1             1.4           872.9
#               2               3             1.4           796.3
#               3               5             1.4           705.7
#               4               6             1.4           814.7
#               5               8             1.4           482.1
#               6              10             1.4           295.7
#               7              11             1.4            45.1
#               8              13             1.4           258.7
#               9              15             1.4           364.9
#              10              15             1.4           364.9
# ---------------------------------------------------------------
# <ipython-input-8-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-8-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
# ---------------------------------------------------------------
#           Orbit       Time (yr)          a (AU)          d (LD)
# ---------------------------------------------------------------
#               0               0             1.4             5.0
#               1               1             1.4           844.8
#               2               3             1.4           942.6
#               3               5             1.4           734.1
#               4               6             1.4           696.8
#               5               8             1.4           806.6
#               6              10             1.4           491.5
#               7              11             1.4           339.4
#               8              13             1.4           208.5
#               9              15             1.4            57.5
#              10              15             1.4            57.5
# ---------------------------------------------------------------
# <ipython-input-8-5144e18e522e>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (15,10))
# <ipython-input-8-5144e18e522e>:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (5,5))
